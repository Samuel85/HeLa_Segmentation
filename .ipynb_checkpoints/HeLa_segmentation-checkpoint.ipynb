# %%
#!pip3 install git+https://github.com/tensorflow/examples.git

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import segmentation_models as sm
sm.set_framework('tf.keras')

import numpy as np
# Out:
# Segmentation Models: using `tf.keras` framework.

# %%
from IPython.display import clear_output
import matplotlib.pyplot as plt
import matplotlib.image as img

# %% [markdown]
# Functions

# %%
def display(display_list,title=['DIC Image', 'User Defined Mask', 'Predicted Mask']):
    plt.figure(figsize=(15, 15))
    for i in range(len(display_list)):
        plt.subplot(1, len(display_list), i+1)
        plt.title(title[i])        
        plt.imshow(tf.keras.preprocessing.image.array_to_img(display_list[i]),cmap=plt.cm.get_cmap("jet"))
        plt.axis('off')
    plt.show()
    
        
def my_generator(gen1, gen2,batch_size=6,training=True):
    while True:
        image_batch, label_batch=next(gen1)[0], np.expand_dims(next(gen2)[0][:,:,0],axis=-1)
        image_batch, label_batch=np.expand_dims(image_batch,axis=0),np.expand_dims(label_batch,axis=0)

        for i in range(batch_size-1):
            image_i,label_i = next(gen1)[0], np.expand_dims(next(gen2)[0][:,:,0],axis=-1)
            
        image_i, label_i=np.expand_dims(image_i,axis=0),np.expand_dims(label_i,axis=0)
        image_batch=np.concatenate([image_batch,image_i],axis=0)
        label_batch=np.concatenate([label_batch,label_i],axis=0)

        yield((image_batch,label_batch))

# Show predictions from the training datasets
def show_predictions(generator=None, num=3):
    if generator == None:        
        generator = train_generator
    for i in range(num):
        image, mask=next(generator)
        sample_image, sample_mask= image[1], mask[1]
        image = np.expand_dims(sample_image, axis=0)

        pr_mask = model.predict(image)
        pr_mask = np.expand_dims(pr_mask[0].argmax(axis=-1),axis=-1)

        display([sample_image, sample_mask,pr_mask])        

# Show predictions and generate time lapses of unlabeled images
def predict(generator=None, num=3, save=False, showplot=True):
    unlabeled_datagen = ImageDataGenerator(rescale=1./255)
    unlabeled_generator = unlabeled_datagen.flow_from_directory(PATH+'test_imgs/',target_size= TARGET_SIZE,batch_size = 1,class_mode = None,shuffle=False)
            
    for i in range(num):        
        image = next(unlabeled_generator)
        mask = model.predict(image)
        mask = np.expand_dims(mask[0].argmax(axis=-1),axis=-1)
        
        mask = mask * [1,1,0]
        mask = mask + 1
        
        img_out = image*mask
        
        #Normalization
        img_out = img_out + np.min(img_out)
        new = (1/(np.max(img_out))) * img_out
                             
        if save == True:
            plt.imsave(OUTPUT_PATH + 'out_'+str(i)+'.png', new[0])
        if showplot==True:
            display([img_out[0]], title=[''])
        else:
            print(i)

# %%
PATH = './train_n_val/'

BATCH_SIZE = 10
LABELS=['background','nucleus','other']

# %%
BATCH_SIZE = 10

# %%
TARGET_SIZE = (224,224)

# %%
LABELS=['background','nucleus','other']

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
)

test_datagen = ImageDataGenerator(
    rescale=1,      
)

val_datagen = ImageDataGenerator(
    rescale=1./255,
)

val_datagen_mask = ImageDataGenerator(
    rescale=1
)


#
train_dataset = train_datagen.flow_from_directory(
    PATH+'train_imgs/',
    target_size= TARGET_SIZE,
    batch_size = BATCH_SIZE,
    class_mode = None,
    seed=123
)

test_dataset = test_datagen.flow_from_directory(
    PATH+'train_masks/',
    target_size= TARGET_SIZE,
    batch_size = BATCH_SIZE,    
    class_mode = None,
    seed=123
)

val_dataset = val_datagen.flow_from_directory(
    PATH+'val_imgs/',
    target_size= TARGET_SIZE,
    batch_size = BATCH_SIZE,        
    class_mode = None,  
    seed=123
)

val_dataset_mask = val_datagen_mask.flow_from_directory(
    PATH+'val_masks/',
    target_size= TARGET_SIZE,
    batch_size = BATCH_SIZE,    
    class_mode = None,
    seed=123
)

train_generator = my_generator(train_dataset, test_dataset, training=False)
val_generator = my_generator(val_dataset, val_dataset_mask, training=False)
# Out:
# Found 39 images belonging to 1 classes.
# Found 39 images belonging to 1 classes.
# Found 17 images belonging to 1 classes.
# Found 17 images belonging to 1 classes.

# %% [markdown]
# Update model with other backbones and weights from the segmentation_models project

# %%
model = sm.Unet('mobilenet',
                encoder_weights='imagenet',
                input_shape=(None,None,3),
                classes=len(LABELS),
                activation='softmax',                 
                encoder_freeze = False)

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy',sm.metrics.IOUScore(threshold=0.5)],
              loss_weights=[1])

# %%
#model.summary()

# %%
EPOCHS = 30
STEPS_PER_EPOCH = 30
VALIDATION_STEPS = 10

model_history = model.fit(train_generator,
                          epochs=EPOCHS,
                          steps_per_epoch=STEPS_PER_EPOCH,
                          validation_data=val_generator,
                          validation_steps=VALIDATION_STEPS)
# Out:
# Epoch 1/30
# /home/samuel/.local/lib/python3.8/site-packages/tensorflow/python/keras/backend.py:4931: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   warnings.warn(
# 30/30 [==============================] - 8s 142ms/step - loss: 0.7873 - accuracy: 0.5088 - iou_score: 0.2039 - val_loss: 1.4682 - val_accuracy: 0.5524 - val_iou_score: 0.2549
# Epoch 2/30
# 30/30 [==============================] - 4s 124ms/step - loss: 0.0782 - accuracy: 0.6323 - iou_score: 0.3206 - val_loss: 0.1914 - val_accuracy: 0.6580 - val_iou_score: 0.3025
# Epoch 3/30
# 30/30 [==============================] - 4s 123ms/step - loss: 0.0482 - accuracy: 0.6324 - iou_score: 0.3232 - val_loss: 0.1679 - val_accuracy: 0.6299 - val_iou_score: 0.3005
# Epoch 4/30
# 30/30 [==============================] - 4s 123ms/step - loss: 0.0400 - accuracy: 0.6404 - iou_score: 0.3242 - val_loss: 0.2593 - val_accuracy: 0.5953 - val_iou_score: 0.2753
# Epoch 5/30
# 30/30 [==============================] - 4s 130ms/step - loss: 0.0332 - accuracy: 0.6479 - iou_score: 0.3252 - val_loss: 0.1306 - val_accuracy: 0.6249 - val_iou_score: 0.2995
# Epoch 6/30
# 30/30 [==============================] - 4s 126ms/step - loss: 0.0314 - accuracy: 0.6363 - iou_score: 0.3259 - val_loss: 0.1070 - val_accuracy: 0.6351 - val_iou_score: 0.3034
# Epoch 7/30
# 30/30 [==============================] - 4s 125ms/step - loss: 0.0291 - accuracy: 0.6332 - iou_score: 0.3264 - val_loss: 0.1068 - val_accuracy: 0.6341 - val_iou_score: 0.3017
# Epoch 8/30
# 30/30 [==============================] - 4s 126ms/step - loss: 0.0262 - accuracy: 0.6331 - iou_score: 0.3268 - val_loss: 0.0948 - val_accuracy: 0.6351 - val_iou_score: 0.3052
# Epoch 9/30
# 30/30 [==============================] - 4s 126ms/step - loss: 0.0249 - accuracy: 0.6354 - iou_score: 0.3274 - val_loss: 0.0671 - val_accuracy: 0.6480 - val_iou_score: 0.3123
# Epoch 10/30
# 30/30 [==============================] - 4s 126ms/step - loss: 0.0225 - accuracy: 0.6323 - iou_score: 0.3280 - val_loss: 0.0375 - val_accuracy: 0.6590 - val_iou_score: 0.3208
# Epoch 11/30
# 30/30 [==============================] - 4s 126ms/step - loss: 0.0226 - accuracy: 0.6345 - iou_score: 0.3280 - val_loss: 0.0434 - val_accuracy: 0.6489 - val_iou_score: 0.3186
# Epoch 12/30
# 30/30 [==============================] - 4s 126ms/step - loss: 0.0207 - accuracy: 0.6453 - iou_score: 0.3281 - val_loss: 0.0253 - val_accuracy: 0.6591 - val_iou_score: 0.3252
# Epoch 13/30
# 30/30 [==============================] - 4s 127ms/step - loss: 0.0212 - accuracy: 0.6515 - iou_score: 0.3280 - val_loss: 0.0239 - val_accuracy: 0.6624 - val_iou_score: 0.3254
# Epoch 14/30
# 30/30 [==============================] - 4s 129ms/step - loss: 0.0216 - accuracy: 0.6412 - iou_score: 0.3280 - val_loss: 0.0293 - val_accuracy: 0.6610 - val_iou_score: 0.3233
# Epoch 15/30
# 30/30 [==============================] - 4s 126ms/step - loss: 0.0207 - accuracy: 0.6360 - iou_score: 0.3284 - val_loss: 0.0275 - val_accuracy: 0.6592 - val_iou_score: 0.3243
# Epoch 16/30
# 30/30 [==============================] - 4s 125ms/step - loss: 0.0190 - accuracy: 0.6348 - iou_score: 0.3289 - val_loss: 0.0313 - val_accuracy: 0.6537 - val_iou_score: 0.3226
# Epoch 17/30
# 30/30 [==============================] - 4s 127ms/step - loss: 0.0177 - accuracy: 0.6395 - iou_score: 0.3293 - val_loss: 0.0196 - val_accuracy: 0.6630 - val_iou_score: 0.3269
# Epoch 18/30
# 30/30 [==============================] - 4s 125ms/step - loss: 0.0161 - accuracy: 0.6385 - iou_score: 0.3296 - val_loss: 0.0166 - val_accuracy: 0.6709 - val_iou_score: 0.3291
# Epoch 19/30
# 30/30 [==============================] - 4s 126ms/step - loss: 0.0183 - accuracy: 0.6383 - iou_score: 0.3290 - val_loss: 0.0167 - val_accuracy: 0.6640 - val_iou_score: 0.3286
# Epoch 20/30
# 30/30 [==============================] - 4s 126ms/step - loss: 0.0183 - accuracy: 0.6355 - iou_score: 0.3292 - val_loss: 0.0156 - val_accuracy: 0.6690 - val_iou_score: 0.3287
# Epoch 21/30
# 30/30 [==============================] - 4s 125ms/step - loss: 0.0156 - accuracy: 0.6394 - iou_score: 0.3299 - val_loss: 0.0168 - val_accuracy: 0.6634 - val_iou_score: 0.3279
# Epoch 22/30
# 30/30 [==============================] - 4s 127ms/step - loss: 0.0153 - accuracy: 0.6335 - iou_score: 0.3299 - val_loss: 0.0165 - val_accuracy: 0.6609 - val_iou_score: 0.3281
# Epoch 23/30
# 30/30 [==============================] - 4s 126ms/step - loss: 0.0155 - accuracy: 0.6352 - iou_score: 0.3300 - val_loss: 0.0192 - val_accuracy: 0.6587 - val_iou_score: 0.3267
# Epoch 24/30
# 30/30 [==============================] - 4s 127ms/step - loss: 0.0155 - accuracy: 0.6382 - iou_score: 0.3296 - val_loss: 0.0158 - val_accuracy: 0.6671 - val_iou_score: 0.3286
# Epoch 25/30
# 30/30 [==============================] - 4s 127ms/step - loss: 0.0151 - accuracy: 0.6384 - iou_score: 0.3300 - val_loss: 0.0151 - val_accuracy: 0.6676 - val_iou_score: 0.3286
# Epoch 26/30
# 30/30 [==============================] - 4s 126ms/step - loss: 0.0154 - accuracy: 0.6428 - iou_score: 0.3297 - val_loss: 0.0190 - val_accuracy: 0.6616 - val_iou_score: 0.3267
# Epoch 27/30
# 30/30 [==============================] - 4s 127ms/step - loss: 0.0156 - accuracy: 0.6402 - iou_score: 0.3295 - val_loss: 0.0235 - val_accuracy: 0.6725 - val_iou_score: 0.3278
# Epoch 28/30
# 30/30 [==============================] - 4s 129ms/step - loss: 0.0168 - accuracy: 0.6429 - iou_score: 0.3292 - val_loss: 0.0145 - val_accuracy: 0.6707 - val_iou_score: 0.3299
# Epoch 29/30
# 30/30 [==============================] - 4s 128ms/step - loss: 0.0156 - accuracy: 0.6325 - iou_score: 0.3300 - val_loss: 0.0135 - val_accuracy: 0.6708 - val_iou_score: 0.3298
# Epoch 30/30
# 30/30 [==============================] - 4s 127ms/step - loss: 0.0142 - accuracy: 0.6372 - iou_score: 0.3302 - val_loss: 0.0131 - val_accuracy: 0.6693 - val_iou_score: 0.3300

# %%
show_predictions()

# %%
#PATH = './timelapse/'
PATH = './timelapse2/'

OUTPUT_PATH = './output/'

# %%
 predict(generator=None, num=2, save=False, showplot=True)
# Out:
# Found 1448 images belonging to 1 classes.
